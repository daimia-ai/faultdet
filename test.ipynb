# %%
# %%shell
# # Notebook'ta her bir degisiklik yaptigin zaman bu hücreyi calistirman yeterli
#
# cd "/content/drive/My Drive/Colab Notebooks/faultdet"
# git pull
# git add -A
# git commit -m "added notebook"
# git push
# Out:
# test
