# %%
# %%shell
# cd "/content/drive/My Drive/Colab Notebooks/faultdet"
# git pull
# git add -A
# git commit -m "added notebook"
# git push
# Out:
# Already up to date.
# [master b84de8f] added notebook
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite test.ipynb (66%)
# remote: Permission to daimia-ai/faultdet.git denied to ahmetnasri-daimia.
# fatal: unable to access 'https://ahmetnasri-daimia:daimia123@github.com/daimia-ai/faultdet/': The requested URL returned error: 403
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-21-105af55f8bcd> in <module>()
# ----> 1 get_ipython().run_cell_magic('shell', '', 'cd "/content/drive/My Drive/Colab Notebooks/faultdet"\ngit pull\ngit add -A\ngit commit -m "added notebook"\ngit push')
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# ...
