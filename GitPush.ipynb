# %%
# %%shell
# cd "/content/drive/My Drive/Colab Notebooks/faultdet"
# git pull
# git add -A
# git commit -m "changed name git push, added surface defect code"
# git push
# Out:
# Already up to date.
# [master b3f060f] changed name git push, added surface defect code
#  3 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 GitPush.ipynb
#  create mode 100644 "surface defect detection.ipynb adl\304\261 not defterinin kopyas\304\261"
#  delete mode 100644 test.ipynb
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 3.10 MiB | 1.47 MiB/s, done.
# Total 4 (delta 0), reused 0 (delta 0)
# To https://github.com/daimia-ai/faultdet
#    bde3038..b3f060f  master -> master
